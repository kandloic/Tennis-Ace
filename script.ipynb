# %% [markdown]
# ### Project Goals (Source: Codecademy)
# The goal of this project is to create a linear regression model that predicts the outcome for a tennis player based on their playing habits. By analyzing and modeling the Association of Tennis Professionals (ATP) data, I am going to try to determine what it takes to be one of the best tennis players in the world.

# %%
import seaborn
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Analysis
# Perform exploratory analysis on the data by plotting different features against the different outcomes. What relationships do you find between the features and outcomes? Do any of the features seem to predict the outcomes?

# %%
df = pd.read_csv('tennis_stats.csv')

# %%
df.head()
# Out:
#                  Player  Year  FirstServe  FirstServePointsWon  \
# 0           Pedro Sousa  2016        0.88                 0.50
# 1       Roman Safiullin  2017        0.84                 0.62
# 2           Pedro Sousa  2017        0.83                 0.60
# 3   Rogerio Dutra Silva  2010        0.83                 0.64
# 4  Daniel Gimeno-Traver  2017        0.81                 0.54
#
#    FirstServeReturnPointsWon  SecondServePointsWon  \
# 0                       0.38                  0.50
# 1                       0.26                  0.33
# 2                       0.28                  0.53
# 3                       0.34                  0.59
# 4                       0.00                  0.33
#
#    SecondServeReturnPointsWon  Aces  BreakPointsConverted  BreakPointsFaced  \
# 0                        0.39     0                  0.14                 7
# 1                        0.07     7                  0.00                 7
# ...

# %%
factors_to_remove = ['Player', 'Year']
df.drop(factors_to_remove, axis=1, inplace=True)
df.head()
# Out:
#    FirstServe  FirstServePointsWon  FirstServeReturnPointsWon  \
# 0        0.88                 0.50                       0.38
# 1        0.84                 0.62                       0.26
# 2        0.83                 0.60                       0.28
# 3        0.83                 0.64                       0.34
# 4        0.81                 0.54                       0.00
#
#    SecondServePointsWon  SecondServeReturnPointsWon  Aces  \
# 0                  0.50                        0.39     0
# 1                  0.33                        0.07     7
# 2                  0.53                        0.44     2
# 3                  0.59                        0.33     2
# 4                  0.33                        0.33     1
#
#    BreakPointsConverted  BreakPointsFaced  BreakPointsOpportunities  \
# 0                  0.14                 7                         7
# 1                  0.00                 7                         0
# ...

# %% [markdown]
# Use one feature from the dataset to build a single feature linear regression model on the data. Your model, at this point, should use only one feature and predict one of the outcome columns. Before training the model, split your data into training and test datasets so that you can evaluate your model on the test set. How does your model perform? Plot your model’s predictions on the test set against the actual outcome variable to visualize the performance.

# %%
x = df[['ServiceGamesPlayed']]
y = df[['Wins']]
X_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)
model = LinearRegression()
model.fit(X_train, y_train)
y_predict = model.predict(x_test)
plt.scatter(y_test, y_predict, alpha = 0.4, color = "red")
plt.show()
model.score(x_test, y_test)
# Out:
# 0.8855623393510854

# %% [markdown]
# Create a few more linear regression models that use one feature to predict one of the outcomes. Which model that you create is the best?

# %%
x2 = df[['BreakPointsFaced']]
y2 = df[['Losses']]
X2_train, x2_test, y2_train, y2_test = train_test_split(x2, y2, test_size=0.2, random_state=1)
model2 = LinearRegression()
model2.fit(X2_train, y2_train)
y2_predict = model2.predict(x2_test)
plt.scatter(y2_test, y2_predict, alpha = 0.4, color = "red")
plt.show()
model.score(x2_test, y2_test)
# Out:
# 0.9004630227868954

# %%
x3 = df[['ServiceGamesPlayed']]
y3 = df[['Winnings']]
X3_train, x3_test, y3_train, y3_test = train_test_split(x3, y3, test_size=0.2, random_state=1)
model3 = LinearRegression()
model3.fit(X3_train, y3_train)
y3_predict = model3.predict(x3_test)
plt.scatter(y3_test, y3_predict, alpha = 0.4, color = "red")
plt.show()
model.score(x3_test, y3_test)
# Out:
# -0.9503767965370684

# %%
df.corr()
# Out:
#                             FirstServe  FirstServePointsWon  \
# FirstServe                    1.000000            -0.070659
# FirstServePointsWon          -0.070659             1.000000
# FirstServeReturnPointsWon     0.025488             0.021729
# SecondServePointsWon          0.101417             0.320765
# SecondServeReturnPointsWon   -0.001924            -0.004724
# Aces                          0.048149             0.460323
# BreakPointsConverted         -0.018877            -0.041538
# BreakPointsFaced              0.057709             0.301925
# BreakPointsOpportunities      0.062345             0.324853
# BreakPointsSaved              0.087945             0.405751
# DoubleFaults                 -0.005477             0.373321
# ReturnGamesPlayed             0.071776             0.375465
# ReturnGamesWon               -0.010676            -0.010193
# ReturnPointsWon               0.004189            -0.002793
# ServiceGamesPlayed            0.071920             0.376460
# ...
